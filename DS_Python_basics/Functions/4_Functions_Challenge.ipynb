# %% [markdown]
# # Challenge

# %% [markdown]
# In this session we will go through problems by building functions from scratch.

# %% [markdown]
# For each problem, you should build a function into your solution. We will build each function into it's own cell, and then call it <br>with different sets of arguments in the next cell and check it until you believe in your functions.

# %% [markdown]
# ## Assignment questions

# %% [markdown]
# 1. Write a program to create a function that takes two arguments, name and age, and print their value.

# %% [markdown]
# Hint: <br>
# - Use the ```def``` keyword with the function name to define a function.
# - Next, take two parameters
# - Print them using the print() function
# - Call function by passing name and age.

# %%
#1
def person(name ="emily",age=30):
    print(name,age)
person("john",34)

# %% [markdown]
# 2. Write a program to create function ```func1()``` to accept a variable length of arguments and print their value.

# %% [markdown]
# **Note:** Create a function in such a way that we can pass any number of arguments to this function, and the function should process<br> them and display each argument’s value.

# %%
# #Hint1:
# # call function with 3 arguments
# func1(20, 40, 60)

# # call function with 2 arguments
# func1(80, 100)

# %%
#Hint2:Expected output
def func1(num):
    for i in num:
        print(i)

func1([20,40,60])
print()
func1([80,100])


# Printing values
# 20
# 40
# 60


# Printing values
# 80
# 100

# %% [markdown]
# 3. Define a function that accepts 2 values and return its sum, subtraction and multiplication.

# %% [markdown]
# **Hint**<br>
# Input:
# - Enter value of a = 7
# - Enter value of b = 5
#
# Expected output <br>
# - Sum is = 12
# - Sub is = 2
# - Multiplication is = 35

# %%
def math_op(a,b):
     sum = a+b
     print("sum is ",sum)
     sub = a-b
     print("sub is",sub)
     multiplication=a*b
     print("multiplication is",multiplication)


math_op(7,5)

# %% [markdown]
# 4. Define a function that accepts roll number and returns whether the student is present or absent.

# %% [markdown]
# **Hint**
# - Use a list to store sample roll. no.
# - Get input from a user and check if the number
# - exist in the list or not, if exists return present
# - else return absent

# %%
def stud_present():
    roll=[i for i in range(1,31)]
    usr_inp = int(input("Enter your roll number"))
    if usr_inp in roll:
        print("Present")
    else:
        print("Absent")

stud_present()

# %% [markdown]
# 5. Define a function which counts vowels and consonant in a word.

# %% [markdown]
# **Hint**<br>
# Input:
# - Enter a word = pythonlobby
#
# **Expected output**
# - Count of vowel is = 2
# - Count of consonant is = 9

# %%
def vov_con():
    string1="aeiouAEIOU"
    vowels=0
    consonants=0
    usr_inp=str(input("Enter the word"))
    for char in usr_inp:
        if char in string1:
            vowels+=1
        else:
            consonants+=1
    print("count of vowel is:",vowels)
    print("count of consonants is:",consonants)
vov_con()

# %% [markdown]
# 6. Define a function that accepts radius and returns the area of a circle.

# %% [markdown]
# **Hint**<br>
# Input:
# - Enter radius  4
#
# **Expected output**
# - Area of a circle is  50.24

# %%
def circle_area():
    radius = float(input("Enter the radius of the circle: "))
    area = 3.14 * radius ** 2
    print(f"The area of the circle with radius {radius} is {area}")
 
circle_area()

# %% [markdown]
# ### Extra chellenge:

# %% [markdown]
# 6. Write a program to create a recursive function to calculate the sum of numbers from 0 to 10.<br>
# A recursive function is a function that calls itself again and again.

# %%
def recur(n):
    if n==0:
        return n
    else:
        return n + recur(n-1)
result = recur(10)
print(result)
# Out:
# 55

# %% [markdown]
# **Expected Output:**<br>
#
# 55

# %% [markdown]
# 7. Create an inner function to calculate the addition in the following way

# %% [markdown]
# - Create an outer function that will accept two parameters, ```a``` and ```b```
# - Create an inner function inside an outer function that will calculate the addition of ```a``` and ```b```
# - At last, an outer function will add 5 into addition and return it

# %%
def out(a,b):
    def inner():
        x=a+b
        return x
    return inner() +5
    
out(1,1)
# Out:
# 7

# %% [markdown]
# 8. Write a function that takes in a list of strings, as well as an inputted substring (i.e. another string), and returns a list of the<br> indices of the strings that contain that inputted substring. For example, if I input ```['This', 'is, 'an' , 'example']``` as the list<br> of strings, and ```is``` as the substring, your function should return ```[0, 1]```.

# %%
def check_strn(x):
    sample = ['This', 'is', 'an' , 'example']
    new_lst =[]
    for i,word in enumerate(sample):
        if x in word:
            new_lst.append(i)
    
    if not new_lst:    #empty check like this
         print("Not found in list")  
    else:
        print(new_lst)
n = str(input("Enter the string"))
check_strn(n)
# Out:
# Not found in list

# %% [markdown]
# **Note:** For more questions to practice, please go through this website: [pynative](https://pynative.com/python-exercises-with-solutions/).

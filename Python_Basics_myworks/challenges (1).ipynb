# %% [markdown]
# # 🐍 Python Challenges – Group Work
#
# These challenges will test your skills in **loops**, **lists**, **sets**, **mutability**, and **if/else** conditions.
# You will work in **two groups**. Each group has a different theme, but both challenges cover the same concepts.
#
# ---
#
# ## **Group 1 Challenge – "Classroom Candy Distribution" 🍬**
#
# **Scenario:**
# You’re helping a teacher distribute candies to students in a fair way.
#
# ### Instructions:
# 1. Start with the following list of student names (some names are duplicated):
#    ```python
#    students = ["Ali", "Sara", "Ali", "John", "Sara", "Maya", "Zain", "Maya", "Omar"]

# %%
students = ["Ali", "Sara", "Ali", "John", "Sara", "Maya", "Zain", "Maya", "Omar"]

# %% [markdown]
# 2. Remove duplicates using a set, then convert back to a list:
#    ```python

# %%
students = ["Ali", "Sara", "Ali", "John", "Sara", "Maya", "Zain", "Maya", "Omar"]
students = set(students)
students1 = list(students)
print(students1)
# Out:
# ['Ali', 'John', 'Zain', 'Sara', 'Maya', 'Omar']

# %% [markdown]
# 3. Each student gets candies based on the length of their name:
#
# - Name length ≤ 4 → 2 candies
# - Name length 5–6 → 3 candies
# - Name length > 6 → 4 candies

# %%
candies = {}
for i in students1:
    if len(i) <= 4:
        candies[i] =2
    elif len(i) == 5 or len(i) == 6:
        candies[i] =3
    else:
        candies[i] =4
print(candies)
# Out:
# {'Ali': 2, 'John': 2, 'Zain': 2, 'Sara': 2, 'Maya': 2, 'Omar': 2}

# %% [markdown]
# 4. Store the result in a list of tuples in the format:
#
# [("Ali", 2), ("Sara", 3), ("John", 3), ...]

# %%
tuple1 = tuple(candies.items())
print(tuple1)
# Out:
# (('Ali', 2), ('John', 2), ('Zain', 2), ('Sara', 2), ('Maya', 2), ('Omar', 2))

# %% [markdown]
# 5. Calculate total candies needed.

# %%
sum =0
dict_1 = dict(tuple1)
for i in dict_1.values():
    sum += i
print(sum)
# Out:
# 12

# %% [markdown]
# 6. Print the results in this format:
#
# Ali gets 2 candies.<br>
# Sara gets 3 candies.<br>
# ...<br>
# Total candies needed: 25<br>

# %%
for x, i in dict_1.items():
    print(f"{x} gets {i} candies")
# Out:
# Ali gets 2 candies
# John gets 2 candies
# Zain gets 2 candies
# Sara gets 2 candies
# Maya gets 2 candies
# Omar gets 2 candies

# %% [markdown]
# # 🏆 Group 2 Challenge – "Sports Tournament Scoring"
#
# **Scenario:**
# You’re in charge of calculating scores for players in a tournament.
#
# ---
#
# ## **Instructions**
# 1. Start with the following list of player names (some names are duplicated):
#    ```python
#    players = ["Lina", "Omar", "Lina", "Hadi", "Omar", "Noor", "Hadi", "Karim"]

# %%
players = ["Lina", "Omar", "Lina", "Hadi", "Omar", "Noor", "Hadi", "Karim"]

# %% [markdown]
# 2. Remove duplicates using a set, then convert back to a list.

# %%
players=set(players)
print(players)
players=list(players)
print(players)
# Out:
# {'Hadi', 'Noor', 'Omar', 'Karim', 'Lina'}
# ['Hadi', 'Noor', 'Omar', 'Karim', 'Lina']

# %% [markdown]
# 3. Each player’s starting score is based on the number of letters in their name:
#
# Name length ≤ 4 → 5 points <br>
# Name length 5–6 → 10 points <br>
# Name length > 6 → 15 points <br>

# %%
candies= {}
for i in players:
    if len(i) <= 4:
        candies[i] = 5 
    elif len(i) == 5 or len(i) ==6:
        candies[i] = 10
    else:
        candies[i] =15
print(candies)
# Out:
# {'Hadi': 5, 'Noor': 5, 'Omar': 5, 'Karim': 10, 'Lina': 5}

# %% [markdown]
# 4. Store the result in a list of tuples in the format:
#
# [("Lina", 5), ("Omar", 5), ("Hadi", 5), ...]

# %%
tuple1 = tuple(candies.items())
print(tuple1)
# Out:
# (('Hadi', 5), ('Noor', 5), ('Omar', 5), ('Karim', 10), ('Lina', 5))

# %% [markdown]
# 5. Calculate total points across all players.

# %%
sum = 0
dict1 = dict(tuple1)
for i in dict1.values():
    sum+=i
print(sum)
# Out:
# 30

# %% [markdown]
# 6. Print the results in this format:
#
# Lina starts with 5 points. <br>
# Omar starts with 5 points. <br>
# ...<br>
# Total points: 50<br>

# %%
for x,i in dict1.items():
    print(f"{x} starts with {i} points")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 for x,i in dict1.items():
#       2     print(f"{x} starts with {i} points")
#
# NameError: name 'dict1' is not defined

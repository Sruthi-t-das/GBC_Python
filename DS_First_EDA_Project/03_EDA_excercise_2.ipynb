# %% [markdown]
# ## EDA Step 1 - Understand your data

# %% [markdown]
# This is just a template for you to use, inorder to perform EDA. Feel free to add as much as lines of code, explanation needed and perform a<br> detailed EDA on the given data!

# %% [markdown]
# For gaining insights about your data, it is necessary to understand your dataset and what it is about. Thus, what you need to do is

# %% [markdown]
# - to read in your data
# - to check how your dataset looks like
# - to check what your columns and rows are about

# %% [markdown]
# **Use your domain knowledge to understand tha data (or the internet)**

# %% [markdown]
# ### Task

# %% [markdown]
# 1. Download the following dataset about Life Expectancy from [kaggle](https://www.kaggle.com/datasets/kumarajarshi/life-expectancy-who?select=Life+Expectancy+Data.csv).

# %%
#Load the required libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# 2. Read in the data (you need to import the necessary library).

# %%
#Load the data
df = pd.read_csv(r'C:\Users\sruth\Documents\Greenbootcamps\DS_First_EDA_Project\data\Life Expectancy Data.csv')

# %% [markdown]
# 3. Explore the dataset (Helpful functions might be df.shape, df.info(), df.columns).

# %%
df.head()
# Out:
#        Country  Year      Status  Life expectancy   Adult Mortality  \
# 0  Afghanistan  2015  Developing              65.0            263.0
# 1  Afghanistan  2014  Developing              59.9            271.0
# 2  Afghanistan  2013  Developing              59.9            268.0
# 3  Afghanistan  2012  Developing              59.5            272.0
# 4  Afghanistan  2011  Developing              59.2            275.0
#
#    infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   ...  \
# 0             62     0.01               71.279624         65.0      1154  ...
# 1             64     0.01               73.523582         62.0       492  ...
# 2             66     0.01               73.219243         64.0       430  ...
# 3             69     0.01               78.184215         67.0      2787  ...
# 4             71     0.01                7.097109         68.0      3013  ...
#
#    Polio  Total expenditure  Diphtheria    HIV/AIDS         GDP  Population  \
# ...

# %%
df.shape
# Out:
# (2938, 22)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2938 entries, 0 to 2937
# Data columns (total 22 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Country                          2938 non-null   object
#  1   Year                             2938 non-null   int64
#  2   Status                           2938 non-null   object
#  3   Life expectancy                  2928 non-null   float64
#  4   Adult Mortality                  2928 non-null   float64
#  5   infant deaths                    2938 non-null   int64
#  6   Alcohol                          2744 non-null   float64
#  7   percentage expenditure           2938 non-null   float64
#  8   Hepatitis B                      2385 non-null   float64
#  9   Measles                          2938 non-null   int64
#  10   BMI                             2904 non-null   float64
#  11  under-five deaths                2938 non-null   int64
# ...

# %%
df.columns
# Out:
# Index(['Country', 'Year', 'Status', 'Life expectancy ', 'Adult Mortality',
#        'infant deaths', 'Alcohol', 'percentage expenditure', 'Hepatitis B',
#        'Measles ', ' BMI ', 'under-five deaths ', 'Polio', 'Total expenditure',
#        'Diphtheria ', ' HIV/AIDS', 'GDP', 'Population',
#        ' thinness  1-19 years', ' thinness 5-9 years',
#        'Income composition of resources', 'Schooling'],
#       dtype='object')

# %% [markdown]
# Also read through the description about the dataset on kaggle.

# %% [markdown]
# 4. Write a short summary what you have learned about the dataset so far.

# %%
#This dataset is about health and socio-economic indicators of countries over several years, with a focus on factors that influence life expectancy.

# %%
#To understand what affects life expectancy in different countries, and how it changes over time, especially between developed and developing countries.

# %% [markdown]
# ## EDA Step 2 - Build hypotheses

# %%
df.head(10)
# Out:
#        Country  Year      Status  Life expectancy   Adult Mortality  \
# 0  Afghanistan  2015  Developing              65.0            263.0
# 1  Afghanistan  2014  Developing              59.9            271.0
# 2  Afghanistan  2013  Developing              59.9            268.0
# 3  Afghanistan  2012  Developing              59.5            272.0
# 4  Afghanistan  2011  Developing              59.2            275.0
# 5  Afghanistan  2010  Developing              58.8            279.0
# 6  Afghanistan  2009  Developing              58.6            281.0
# 7  Afghanistan  2008  Developing              58.1            287.0
# 8  Afghanistan  2007  Developing              57.5            295.0
# 9  Afghanistan  2006  Developing              57.3            295.0
#
#    infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   ...  \
# 0             62     0.01               71.279624         65.0      1154  ...
# ...

# %%
df1 = df.query("Status == 'Developed'")
df1.head()
# Out:
#        Country  Year     Status  Life expectancy   Adult Mortality  \
# 112  Australia  2015  Developed              82.8             59.0
# 113  Australia  2014  Developed              82.7              6.0
# 114  Australia  2013  Developed              82.5             61.0
# 115  Australia  2012  Developed              82.3             61.0
# 116  Australia  2011  Developed              82.0             63.0
#
#      infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   \
# 112              1      NaN                 0.00000         93.0        74
# 113              1     9.71             10769.36305         91.0       340
# 114              1     9.87             11734.85381         91.0       158
# 115              1    10.03             11714.99858         91.0       199
# 116              1    10.30             10986.26527         92.0       190
#
#      ...  Polio  Total expenditure  Diphtheria    HIV/AIDS          GDP  \
# ...

# %% [markdown]
# To Do's:
# - What are your assumptions?
# - Ask yourself questions!

# %%
#How the Life expectency differ across countries over time
#Is there any relation between the  Life expectency rate and status of the country(developing or developed)
#What factors are most associated with longer life expectancy?

# %% [markdown]
# What is the conclusion or what does it mean if all your hypothesis are confirmed?

# %% [markdown]
# ### Task

# %% [markdown]
# For the Life Expectancy dataset, create 5 hypotheses you want to follow during the following analysis.

# %%
#when gdp increaces life expectancy increaces 
#Developed countries have a higher life expectancy than developing countries
#higher rate of Schooling for developed countries

# %% [markdown]
# **These hypotheses will guide your following analysis!**

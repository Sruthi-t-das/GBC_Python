# %% [markdown]
# ## Practice session 2

# %% [markdown]
# So we have done some analysis with the help of instructions. Let's try it all alone using a different dataset!!

# %% [markdown]
# For this task, we will be using ```Iris dataset```. It's all about plant ```Iris```. Let's learn more about this plant. This data is<br> available in the folder ```data/Iris.csv```.

# %% [markdown]
# ## Objectives

# %% [markdown]
# By the end of this notebook, you will learn to
# - load data from a csv files into a DataFrame
# - access data stored in a dataframe
# - use the general functions of a DataFrame to answer questions about the data
# - create insightful plots using the pandas function ```.plot()```
# - List the findings that you draw from these visualizations.

# %%
# import pandas
import pandas as pd
import matplotlib.pyplot as plt

# %%
# load the data
df = pd.read_csv('data/Iris.csv')

# %% [markdown]
# Follow the questions below and try to fill in the code cells below accordingly!

# %% [markdown]
# Let's look at the head of the table:

# %%
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %% [markdown]
# And the last 10 rows of the table:

# %%
df.tail(10)
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 140  141            6.7           3.1            5.6           2.4
# 141  142            6.9           3.1            5.1           2.3
# 142  143            5.8           2.7            5.1           1.9
# 143  144            6.8           3.2            5.9           2.3
# 144  145            6.7           3.3            5.7           2.5
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 140  Iris-virginica
# 141  Iris-virginica
# 142  Iris-virginica
# 143  Iris-virginica
# 144  Iris-virginica
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# ...

# %% [markdown]
# Get the shape of the dataset

# %%
df.shape
# Out:
# (150, 6)

# %% [markdown]
# How many irises are in the data set?

# %%
df['Species'].unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %% [markdown]
# Check for missing values in the dataset

# %%
df.info()
df.notnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB
# Id               150
# SepalLengthCm    150
# SepalWidthCm     150
# PetalLengthCm    150
# PetalWidthCm     150
# Species          150
# dtype: int64

# %% [markdown]
# Check whether the no. of entries in the 3 species are balanced

# %%
#df.value_counts("Species") 
df.groupby('Species').count()  #yes it is balanced
# Out:
#                  Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# Species
# Iris-setosa      50             50            50             50            50
# Iris-versicolor  50             50            50             50            50
# Iris-virginica   50             50            50             50            50

# %% [markdown]
# Calculate the mean, median, mode for petal length

# %%
print('Mean: ', df.PetalLengthCm.mean())
print('Median: ', df.PetalLengthCm.median())
print('Mode: ', df.PetalLengthCm.mode()[0])
# Out:
# Mean:  3.758666666666666
# Median:  4.35
# Mode:  1.5

# %% [markdown]
# What can you conclude about the distribution for petal length?

# %%
df[['PetalLengthCm']].plot(kind='box')  #the mean is smaller than the median
# Out:
# <Axes: >

# %% [markdown]
# What is the smallest and largest value for petal length?

# %%
# df.describe()

print('Largest value: ', df.PetalLengthCm.max())
print('Smallest value: ', df.PetalLengthCm.min())
# Out:
# Largest value:  6.9
# Smallest value:  1.0

# %% [markdown]
# Calculate the variance and standard deviation for petal length

# %%
print('variance: ', df.PetalLengthCm.var())  #It’s the average of the squared differences from the mean.
print('standard deviation: ', df.PetalLengthCm.std())
# Out:
# variance:  3.113179418344519
# standard deviation:  1.7644204199522626

# %% [markdown]
# Calculate the basic descriptive statistics for all columns of the iris data set with a single command.

# %%
df.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %% [markdown]
# What is the overall average for sepal length?

# %%
# print('Average: ', df.SepalLengthCm.mean())
print('Average: ', df['SepalLengthCm'].mean())
# Out:
# Average:  5.843333333333334

# %% [markdown]
# Use DataFrame grouping function to determine the count by species.

# %%
df.groupby('Species').count()['Id']
# Out:
# Species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: Id, dtype: int64

# %% [markdown]
# Use DataFrame grouping function to determine the average length and width of sepals and pedals by species.

# %%
df.groupby('Species')[['PetalWidthCm', 'SepalWidthCm']].mean().head(5)
# Out:
#                  PetalWidthCm  SepalWidthCm
# Species
# Iris-setosa             0.244         3.418
# Iris-versicolor         1.326         2.770
# Iris-virginica          2.026         2.974

# %% [markdown]
# Add the sum of the sepal width and length as a new column to your data frame.

# %%
df.eval('TotalSepalCm = SepalLengthCm + SepalWidthCm',inplace=True)
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species  \
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa
#
#    Totalsepal  TotalSepalCm
# 0         8.6           8.6
# 1         7.9           7.9
# 2         7.9           7.9
# 3         7.7           7.7
# 4         8.6           8.6

# %% [markdown]
# Visualize petal length with a histogram

# %%
df['PetalLengthCm'].plot(kind='hist',xlabel='Petal_Length')
# Out:
# <Axes: xlabel='Petal_Length', ylabel='Frequency'>

# %% [markdown]
# Compare the Petal Length and Petal Width using a scatter plot

# %%
df.plot(kind='scatter', x='PetalLengthCm', y='PetalWidthCm')
# Out:
# <Axes: xlabel='PetalLengthCm', ylabel='PetalWidthCm'>

# %% [markdown]
# Describe the distribution

# %%
# It increasing together as length increase  width also increasing

# %% [markdown]
# Which is more informative: the summary statistics or visualizations?

# %%
#table is more give precise numerical insights,so summary statistics is better

# %% [markdown]
# Visualize petal length and width with a "scatter_matrix"

# %%
pd.plotting.scatter_matrix(df[['PetalWidthCm', 'PetalLengthCm']])
# Out:
# array([[<Axes: xlabel='PetalWidthCm', ylabel='PetalWidthCm'>,
#         <Axes: xlabel='PetalLengthCm', ylabel='PetalWidthCm'>],
#        [<Axes: xlabel='PetalWidthCm', ylabel='PetalLengthCm'>,
#         <Axes: xlabel='PetalLengthCm', ylabel='PetalLengthCm'>]],
#       dtype=object)

# %% [markdown]
# Create a new column with a rough estimate of petal area by multiplying petal length and width together.

# %%
df.eval('PetalArea = PetalLengthCm * PetalWidthCm',inplace=True)
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species  \
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa
#
#    Totalsepal  TotalSepalCm  PetalArea
# 0         8.6           8.6       0.28
# 1         7.9           7.9       0.28
# 2         7.9           7.9       0.26
# 3         7.7           7.7       0.30
# 4         8.6           8.6       0.28

# %% [markdown]
# Create a new dataframe with petal areas greater than ```1cm^2```

# %%
df_new = df.query('PetalArea>1')
df_new.head(5)
# Out:
#     Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 50  51            7.0           3.2            4.7           1.4
# 51  52            6.4           3.2            4.5           1.5
# 52  53            6.9           3.1            4.9           1.5
# 53  54            5.5           2.3            4.0           1.3
# 54  55            6.5           2.8            4.6           1.5
#
#             Species  Totalsepal  TotalSepalCm  PetalArea
# 50  Iris-versicolor        10.2          10.2       6.58
# 51  Iris-versicolor         9.6           9.6       6.75
# 52  Iris-versicolor        10.0          10.0       7.35
# 53  Iris-versicolor         7.8           7.8       5.20
# 54  Iris-versicolor         9.3           9.3       6.90

# %% [markdown]
# Create 3 new dataframes, one for each species. Use the entire dataset.

# %%
df['Species'].unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
# Irissetosa = df[df.Species == 'Iris-setosa']
# Irissetosa = df[df['Species'] == 'Iris-setosa']
df_new = df.query("Species == 'Iris-setosa'")
Irissetosa.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species  \
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa
#
#    Totalsepal  TotalSepalCm  PetalArea
# 0         8.6           8.6       0.28
# 1         7.9           7.9       0.28
# 2         7.9           7.9       0.26
# 3         7.7           7.7       0.30
# 4         8.6           8.6       0.28

# %%
Irisversicolor = df[df.Species == 'Iris-versicolor']
Irisversicolor.head()
# Out:
#     Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 50  51            7.0           3.2            4.7           1.4
# 51  52            6.4           3.2            4.5           1.5
# 52  53            6.9           3.1            4.9           1.5
# 53  54            5.5           2.3            4.0           1.3
# 54  55            6.5           2.8            4.6           1.5
#
#             Species  Totalsepal  TotalSepalCm  PetalArea
# 50  Iris-versicolor        10.2          10.2       6.58
# 51  Iris-versicolor         9.6           9.6       6.75
# 52  Iris-versicolor        10.0          10.0       7.35
# 53  Iris-versicolor         7.8           7.8       5.20
# 54  Iris-versicolor         9.3           9.3       6.90

# %%
Irisvirginica = df[df.Species == 'Iris-virginica']
Irisvirginica.head()
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 100  101            6.3           3.3            6.0           2.5
# 101  102            5.8           2.7            5.1           1.9
# 102  103            7.1           3.0            5.9           2.1
# 103  104            6.3           2.9            5.6           1.8
# 104  105            6.5           3.0            5.8           2.2
#
#             Species  Totalsepal  TotalSepalCm  PetalArea
# 100  Iris-virginica         9.6           9.6      15.00
# 101  Iris-virginica         8.5           8.5       9.69
# 102  Iris-virginica        10.1          10.1      12.39
# 103  Iris-virginica         9.2           9.2      10.08
# 104  Iris-virginica         9.5           9.5      12.76

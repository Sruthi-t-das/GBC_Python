# %% [markdown]
# # Data visualization using Seaborn

# %% [markdown]
# **```Seaborn```** is a library mostly used for statistical plotting in Python. It is built on top of Matplotlib and provides beautiful<br> default styles and color palettes to make statistical plots more attractive.

# %% [markdown]
# By the end of thie notebook, you will learn:
# - about Python Seaborn from basics to advance using a dataset
# - different graphs that can be plotted using Seaborn.

# %% [markdown]
# First of all, let us install Seaborn. Seaborn can be installed using the pip. Type the below command in the terminal.

# %%
#pip install seaborn

# %% [markdown]
# **Note:** Seaborn has the following dependencies_
#
# - Python 2.7 or 3.4+
# - numpy
# - scipy
# - pandas
# - matplotlib

# %% [markdown]
# Let's see an example of a simple plot using Seaborn. We will be plotting a simple line plot using the same iris dataset that we used<br> before. Iris dataset contains five columns such as Petal Length, Petal Width, Sepal Length, Sepal Width and Species Type. Iris is a<br> flowering plant, the researchers have measured various features of the different iris flowers and recorded them digitally.

# %% [markdown]
# Example:

# %%
# importing packages 
import seaborn as sns 
  
# loading dataset 
data = sns.load_dataset("iris") 
  
# draw lineplot 
sns.lineplot(x="sepal_length", y="sepal_width", data=data)
# Out:
# <Axes: xlabel='sepal_length', ylabel='sepal_width'>

# %% [markdown]
# In the above example, a simple line plot is created using the ```.lineplot()``` method. Do not worry about these functions as we will be<br> discussing them in detail in the below sections.

# %% [markdown]
# The line shadow represents the 95% confidence interval of the estimate.

# %% [markdown]
# If you want to know more on Seaborn, please have a look in to the following documents:
# - [Introduction to Seaborn – Python](https://www.geeksforgeeks.org/introduction-to-seaborn-python/)
# - [Plotting graph using Seaborn](https://www.geeksforgeeks.org/plotting-graph-using-seaborn-python/)

# %% [markdown]
# In the introduction, you must have read that Seaborn is built on the top of Matplotlib. It means that Seaborn can be used with Matplotlib.

# %% [markdown]
# ## Using Seaborn with Matplotlib

# %% [markdown]
# Using both Matplotlib and Seaborn together is a very simple process. We just have to invoke the Seaborn Plotting function as normal, and<br> then we can use Matplotlib’s customization function.

# %% [markdown]
# **Example 1**: We will be using the above example and will add the title to the plot using the Matplotlib.

# %%
# importing packages
import seaborn as sns
import matplotlib.pyplot as plt

# loading dataset
data = sns.load_dataset("iris")

# draw lineplot
sns.lineplot(x="sepal_length", y="sepal_width", data=data)

# setting the title using Matplotlib
plt.title('Title using Matplotlib Function')

plt.show()

# %% [markdown]
# **Example 2**: Setting the xlim and ylim:

# %%
# importing packages
import seaborn as sns
import matplotlib.pyplot as plt

# loading dataset
data = sns.load_dataset("iris")

# draw lineplot
sns.lineplot(x="sepal_length", y="sepal_width", data=data)

# setting the x limit of the plot
plt.xlim(5)

plt.show()

# %% [markdown]
# ## Customising Seaborn plots

# %% [markdown]
# Seaborn comes with some customized themes and a high-level interface for customizing the looks of the graphs. Consider the above example<br> where the default of the Seaborn is used. It still looks nice and pretty but we can customize the graph according to our own needs. So<br> let’s see the styling of plots in detail.

# %% [markdown]
# ```set_style()``` method is used to set the aesthetic of the plot. It means it affects things like the color of the axes, whether the grid is<br> active or not, or other aesthetic elements. There are five themes available in Seaborn.

# %% [markdown]
# - darkgrid
# - whitegrid
# - dark
# - white
# - ticks

# %% [markdown]
# **Syntax**

# %% [markdown]
# ```set_style(style=None, rc=None)```

# %% [markdown]
# **Example**: Using the dark theme

# %%
# importing packages 
import seaborn as sns 
import matplotlib.pyplot as plt 
  
# loading dataset 
data = sns.load_dataset("iris") 
  
# draw lineplot 
sns.lineplot(x="sepal_length", y="sepal_width", data=data) 
  
# changing the theme to dark
sns.set_style("dark")
plt.show()

# %% [markdown]
# ## Changing the figure Size

# %% [markdown]
# The figure size can be changed using the figure() method of Matplotlib. ```figure()``` method creates a new figure of the specified size passed<br> in the figsize parameter.

# %%
# importing packages 
import seaborn as sns 
import matplotlib.pyplot as plt 
  
# loading dataset 
data = sns.load_dataset("iris") 
  
# changing the figure size
plt.figure(figsize = (2, 4))
  
# draw lineplot 
sns.lineplot(x="sepal_length", y="sepal_width", data=data) 
  
# Removing the spines
sns.despine()
  
plt.show()

# %% [markdown]
# ## Setting the Style Temporarily

# %% [markdown]
# ```axes_style()``` method is used to set the style temporarily. It is used along with the with statement.

# %% [markdown]
# **Syntax**

# %% [markdown]
# ```axes_style(style=None, rc=None)```

# %% [markdown]
# **Example**

# %%
# importing packages
import seaborn as sns
import matplotlib.pyplot as plt

# loading dataset
data = sns.load_dataset("iris")


def plot():
	sns.lineplot(x="sepal_length", y="sepal_width", data=data)

with sns.axes_style('darkgrid'):
	
	# Adding the subplot
	plt.subplot(211)
	plot()
	
plt.subplot(212)
plot()

# %% [markdown]
# To know more about styling, please refer to the following document:
# - [Seaborn : Style And Color](https://www.geeksforgeeks.org/seaborn-style-and-color/)

# %% [markdown]
# other important aspect of Seaborn is setting the colour Palette. We are not going to discuss this in details here. If you are interested <br> to know more about different colours that are available with this, please refer : [Seaborn color palette](https://www.geeksforgeeks.org/seaborn-color-palette/).

# %% [markdown]
# ## Multiple plots with Seaborn

# %% [markdown]
# You might have seen multiple plots in the above examples and some of you might have got confused. Don’t worry we will cover multiple plots<br> in this section. Multiple plots in Seaborn can also be created using the Matplotlib as well as Seaborn also provides some functions for the<br> same.

# %% [markdown]
# ### Using Matplotlib

# %% [markdown]
# Matplotlib provides various functions for plotting subplots. Some of them are ```add_axes()```, ```subplot()```, and ```subplot2grid()```. Let’s see an<br> example of each function for better understanding.

# %% [markdown]
# **Example1**: Using ```add_axes()```:

# %%
# importing packages
import seaborn as sns
import matplotlib.pyplot as plt


# loading dataset
data = sns.load_dataset("iris")

def graph():
	sns.lineplot(x="sepal_length", y="sepal_width", data=data)

# Creating a new figure with width = 5 inches
# and height = 4 inches
fig = plt.figure(figsize =(5, 4))

# Creating first axes for the figure
ax1 = fig.add_axes([0.1, 0.1, 0.8, 0.8])

# plotting the graph
graph()

# Creating second axes for the figure
ax2 = fig.add_axes([0.5, 0.5, 0.3, 0.3])

# plotting the graph
graph()

plt.show()

# %% [markdown]
# **Example 2**: Using ```subplot()``` method

# %%
# importing packages
import seaborn as sns
import matplotlib.pyplot as plt

# loading dataset
data = sns.load_dataset("iris")

 
def graph():
	sns.lineplot(x="sepal_length", y="sepal_width", data=data)

# Adding the subplot at the specified
# grid position
plt.subplot(121)
graph()

# Adding the subplot at the specified
# grid position
plt.subplot(122)
graph()

plt.show()

# %% [markdown]
# **Example 3**: Using ```subplot2grid()``` method

# %%
# importing packages
import seaborn as sns
import matplotlib.pyplot as plt

# loading dataset
data = sns.load_dataset("iris")

def graph():
	sns.lineplot(x="sepal_length", y="sepal_width", data=data)

	# ''' axes1 = plt.subplot2grid (
# (7, 1), (0, 0), rowspan = 2, colspan = 1)
# (7,1): shape: Total grid size (rows, columns)
 
# (0,0) location: Top-left cell where this subplot begins
 
# rowspan: How many rows this subplot spans
 
# colspan: How many columns this subplot spans'''

# adding the subplots
axes1 = plt.subplot2grid (
(7, 1), (0, 0), rowspan = 2, colspan = 1)
graph()

axes2 = plt.subplot2grid (
(7, 1), (2, 0), rowspan = 2, colspan = 1)
graph()
	
axes3 = plt.subplot2grid (
(7, 1), (4, 0), rowspan = 2, colspan = 1)
graph()

# %% [markdown]
# ### Using Seaborn

# %% [markdown]
# Seaborn also provides some functions for plotting multiple plots. Let’s see them in detail

# %% [markdown]
# **Method 1**: Using ```FacetGrid()``` method

# %% [markdown]
# - FacetGrid class helps in visualizing distribution of one variable as well as the relationship between multiple variables separately<br> within subsets of your dataset using multiple panels.
# - A FacetGrid can be drawn with up to three dimensions ? row, col, and hue. The first two have obvious correspondence with the resulting<br> array of axes; think of the hue variable as a third dimension along a depth axis, where different levels are plotted with different colors.
# - FacetGrid object takes a dataframe as input and the names of the variables that will form the row, column, or hue dimensions of the grid.<br> The variables should be categorical and the data at each level of the variable will be used for a facet along that axis.

# %% [markdown]
# **Syntax:**

# %% [markdown]
# ```seaborn.FacetGrid( data, \*\*kwargs)```

# %% [markdown]
# **Example**

# %%
# importing packages
import seaborn as sns
import matplotlib.pyplot as plt

# loading dataset
data = sns.load_dataset("iris")

plot = sns.FacetGrid(data, col="species")
plot.map(plt.plot, "sepal_width")

plt.show()

# %% [markdown]
# **Method 2**: Using ```PairGrid()``` method

# %% [markdown]
# - Subplot grid for plotting pairwise relationships in a dataset.
# - This class maps each variable in a dataset onto a column and row in a grid of multiple axes. Different axes-level plotting functions can<br> be used to draw bivariate plots in the upper and lower triangles, and the marginal distribution of each variable can be shown on the<br> diagonal.
# - It can also represent an additional level of conventionalization with the hue parameter, which plots different subsets of data in<br> different colors. This uses color to resolve elements on a third dimension, but only draws subsets on top of each other and will not<br> tailor the hue parameter for the specific visualization the way that axes-level functions that accept hue will.

# %% [markdown]
# **Syntax:**

# %% [markdown]
# ```seaborn.PairGrid( data, \*\*kwargs)```

# %% [markdown]
# **Example:**

# %%
# importing packages
import seaborn as sns
import matplotlib.pyplot as plt

# loading dataset
data = sns.load_dataset("flights")

plot = sns.PairGrid(data)
plot.map(plt.plot)

plt.show()

# %% [markdown]
# If you want to know more about these methods, please refer:
# - [Python – seaborn.FacetGrid() method](https://www.geeksforgeeks.org/python-seaborn-facetgrid-method/)
# - [Python – seaborn.PairGrid() method](https://www.geeksforgeeks.org/python-seaborn-pairgrid-method/)

# %% [markdown]
# ## Creating different types of plots

# %% [markdown]
# ### Relational plots

# %% [markdown]
# **Relational plots** are used for visualizing the statistical relationship between the data points. Visualization is necessary because it<br> allows the human to see trends and patterns in the data.

# %% [markdown]
# ### **Relplot()**

# %% [markdown]
# This function provides us the access to some other different axes-level functions which shows the relationships between two variables with<br> semantic mappings of subsets. It is plotted using the **relplot()** method.

# %% [markdown]
# **Syntax:**

# %% [markdown]
# ```seaborn.relplot(x=None, y=None, data=None, **kwargs) ```

# %% [markdown]
# **Example:**

# %%
# importing packages
import seaborn as sns
import matplotlib.pyplot as plt

# loading dataset
data = sns.load_dataset("iris")

# creating the relplot
sns.relplot(x='sepal_width', y='species', data=data,col='species')

plt.show()

# %% [markdown]
# ### **Scatterplot**

# %% [markdown]
# The scatter plot is a mainstay of statistical visualization. It depicts the joint distribution of two variables using a cloud of points, where each<br> point represents an observation in the dataset. This depiction allows the eye to infer a substantial amount of information about whether<br> there is any meaningful relationship between them. It is plotted using the ```scatterplot()``` method.

# %% [markdown]
# **Syntax:**

# %% [markdown]
# ```seaborn.scatterplot(x=None, y=None, data=None, **kwargs)```

# %% [markdown]
# **Example:**

# %%
# importing packages
import seaborn as sns
import matplotlib.pyplot as plt

# loading dataset
data = sns.load_dataset("iris")

sns.scatterplot(x='sepal_length', y='sepal_width', data=data,hue='species')
plt.show()

# %% [markdown]
# To know more about scatterplot in Seaborn, read this [Scatterplot using Seaborn in Python](https://www.geeksforgeeks.org/scatterplot-using-seaborn-in-python/)

# %% [markdown]
# ### **Line plot**

# %% [markdown]
# As you will remember, we have already used this kind of plot before.

# %% [markdown]
# **Syntax**

# %% [markdown]
# ```seaborn.lineplot(x=None, y=None, data=None, **kwargs)```

# %% [markdown]
# **Example**

# %%
# importing packages
import seaborn as sns
import matplotlib.pyplot as plt

# loading dataset
data = sns.load_dataset("iris")

sns.lineplot(x='sepal_length', y='species', data=data)
plt.show()

# %% [markdown]
# ### **Categorical Plots**

# %% [markdown]
# [Categorical Plots](https://www.geeksforgeeks.org/seaborn-categorical-plots/) are used where we have to visualize relationship between two numerical values. A more specialized approach can be used if<br> one of the main variable is [categorical](https://www.geeksforgeeks.org/exploring-categorical-data/) which means such variables that take on a fixed and limited number of possible values.

# %% [markdown]
# There are various types of categorical plots let’s discuss each one them in detail below.

# %% [markdown]
# ### **Bar plot**

# %% [markdown]
# A barplot is basically used to aggregate the categorical data according to some methods and by default its the mean. It can also be<br> understood as a visualization of the group by action. To use this plot we choose a categorical column for the x axis and a numerical column<br> for the y axis and we see that it creates a plot taking a mean per categorical column. It can be created using the ```barplot()``` method.

# %% [markdown]
# **Syntax**

# %% [markdown]
# ```barplot([x, y, hue, data, order, hue_order, …])```

# %% [markdown]
# **Example**

# %%
# importing packages
import seaborn as sns
import matplotlib.pyplot as plt

# loading dataset
data = sns.load_dataset("iris")

sns.barplot(x='species', y='sepal_length', data=data,hue='species')
plt.show()

# %% [markdown]
# Read [here](https://www.geeksforgeeks.org/barplot-using-seaborn-in-python/) to know more about Barplots.

# %% [markdown]
# ### **Count plot**

# %% [markdown]
# A countplot basically counts the categories and returns a count of their occurrences. It is one of the most simple plots provided by the<br> seaborn library. It can be created using the ```countplot()``` method.

# %% [markdown]
# **Syntax**

# %% [markdown]
# ```countplot([x, y, hue, data, order, …])```

# %% [markdown]
# **Example:**

# %%
# importing packages
import seaborn as sns
import matplotlib.pyplot as plt

# loading dataset
data = sns.load_dataset("iris")

sns.countplot(x='species', data=data,hue='species')
plt.show()

# %% [markdown]
# Read [here](https://www.geeksforgeeks.org/countplot-using-seaborn-in-python/) to know more on Count plot.

# %% [markdown]
# ### **Box plot**

# %% [markdown]
# A boxplot is sometimes known as the box and whisker plot.It shows the distribution of the quantitative data that represents the comparisons<br> between variables. boxplot shows the quartiles of the dataset while the whiskers extend to show the rest of the distribution i.e. the dots<br> indicating the presence of outliers. It is created using the ```boxplot()``` method.

# %% [markdown]
# **Syntax**

# %% [markdown]
# ```boxplot([x, y, hue, data, order, hue_order, …])```

# %% [markdown]
# **Example:**

# %%
# importing packages
import seaborn as sns
import matplotlib.pyplot as plt

# loading dataset
data = sns.load_dataset("iris")

sns.boxplot(x='species', y='sepal_width', data=data,hue='species')
plt.show()

# %% [markdown]
# To know more about Box plot, read these documents:
# - [Boxplot](https://www.geeksforgeeks.org/boxplot-using-seaborn-in-python/)
# - [Horizontal Boxplot](https://www.geeksforgeeks.org/horizontal-boxplots-with-seaborn-in-python/)

# %% [markdown]
# There are other plots such as Violin plot, Stripplot etc.. Go through the following documents to know more:

# %% [markdown]
# - [Violinplot](geeksforgeeks.org/violinplot-using-seaborn-in-python/)
# - [Stripplot](https://www.geeksforgeeks.org/stripplot-using-seaborn-in-python/)
# - [Factorplot](https://www.geeksforgeeks.org/python-seaborn-factorplot-method/)

# %% [markdown]
# ### **Distribution plots**

# %% [markdown]
# **Distribution Plots** are used for examining univariate and bivariate distributions meaning such distributions that involve one variable or<br> two discrete variables.

# %% [markdown]
#  There are various types of distribution plots let’s discuss each one them in detail.

# %% [markdown]
# ### **Histogram**

# %% [markdown]
# A histogram is basically used to represent data provided in a form of some groups.It is accurate method for the graphical representation of<br> numerical data distribution. It can be plotted using the ```histplot()``` function.

# %% [markdown]
# **Syntax:**

# %% [markdown]
# ```histplot(data=None, *, x=None, y=None, hue=None,  **kwargs)```

# %% [markdown]
# **Example:**

# %%
# importing packages
import seaborn as sns
import matplotlib.pyplot as plt

# loading dataset
data = sns.load_dataset("iris")

sns.histplot(x='species', y='sepal_width', data=data,hue='species')
plt.show()

# %% [markdown]
# ### **Distplot**

# %% [markdown]
# Distplot is used basically for univariant set of observations and visualizes it through a histogram i.e. only one observation and hence we<br> choose one particular column of the dataset. It is potted using the ```distplot()``` method.

# %% [markdown]
# **Syntax**

# %% [markdown]
# ```distplot(a[, bins, hist, kde, rug, fit, …])```

# %% [markdown]
# **Example:**

# %%
# importing packages
import seaborn as sns
import matplotlib.pyplot as plt

# loading dataset
data = sns.load_dataset("iris")

sns.displot(data['sepal_width'])
plt.show()

# %% [markdown]
# ### **Pairplot**

# %% [markdown]
# Another important plot to know while analysing a data is **Pairplot**. **Pairplot** represents pairwise relation across the entire dataframe<br> and supports an additional argument called hue for categorical separation. What it does basically is create a jointplot between<br> every possible numerical column and takes a while if the dataframe is really huge. It is plotted using the ```pairplot()``` method.

# %% [markdown]
# **Syntax**

# %% [markdown]
# ```pairplot(data[, hue, hue_order, palette, …])```

# %% [markdown]
# **Example:**

# %%
# importing packages
import seaborn as sns
import matplotlib.pyplot as plt

# loading dataset
data = sns.load_dataset("iris")

sns.pairplot(data=data, hue='species')
plt.show()

# %% [markdown]
# Read more about Paiplot [here](https://www.geeksforgeeks.org/data-visualization-with-pairplot-seaborn-and-pandas/).

# %% [markdown]
# There are two more plots which are important for you to know. Thae are [Matrix plots](https://www.geeksforgeeks.org/ml-matrix-plots-in-seaborn/) and [Heatmap](https://www.geeksforgeeks.org/seaborn-heatmap-a-comprehensive-guide/). We will be dealing with that in the later part of this<br> course anyways. Let's keep it for then!!

# %% [markdown]
# Was it a lot?? Don't worry!! This is just the introduction. We will be using these plots in almost all the sessions from here onwards<br>. So there is enough time for you to understand it clearly.

# %% [markdown]
# Also there will be a groupwork lateron for you to use all these modules and to visualize a given dataset and comeup with conclusions!

# %% [markdown]
# But now you know that ```Seaborn``` is such a powerful tool in Python!!

# %% [markdown]
# # Pandas Visualization

# %% [markdown]
# There are several libraries available in pandas to do visualization and we'll be mostly using [Matplotlib](https://matplotlib.org/). But most of the times, you may<br> see people using [Seaborn](http://seaborn.pydata.org/)(you will be learningsoon) to visualize the data. Some other popular tool is [Plotly](https://plotly.com/) which is used in some<br> specialized cases (such as dashboards).

# %% [markdown]
# If we look at the [document](https://pandas.pydata.org/pandas-docs/stable/user_guide/visualization.html), we can see that the plotting available with pandas will be called via the ```plot()``` method on a DataFrame object. From<br> there, we'll pass in a bunch of potential arguments to the ```plot()``` method to specify exactly how to build the plot. The most important of<br> those arguments is the kind keyword argument, which tells the ```plot()``` method what kind of visualization we would like (bar plot, histogram,<br> scatter plot, etc.). Most of the time we'll be doing your visualization in Matplotlib or Seaborn, but here is a little taste of what pandas<br> can do so that you know it's there.

# %% [markdown]
# Here we will explore Red-wine data for this pourpose. We have already seen a similar dataset in the previous notebook. This will be an<br> extention of that. But here we will more focus on visualizing the data using pandas.

# %% [markdown]
# ## Objectives:

# %% [markdown]
# By the end of this notebook, you will be able to:
# - create plots with the pandas function ```.plot()```
# - describe the different kinds of plots (eg. histograms, scatter plots, bar plots and box plots)
# - explain what conclusions you draw from these plots

# %% [markdown]
# Let's start by importing pandas!

# %%
import pandas as pd
df = pd.read_csv('data/winequality-red.csv', delimiter=';')

# %%
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
df.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %%
df.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %% [markdown]
# We have several input variables such as:
#
# 1. fixed acidity
# 2. volatile acidity
# 3. citric acid
# 4.  residual sugar
# 5. chlorides
# 6. free sulfur dioxide
# 7. total sulfur dioxide
# 8. density
# 9. pH
# 10. sulphates
# 11. alcohol

# %% [markdown]
# And there is one output variable, i.e,
#
# 12. quality (which is a score between 0 and 10)

# %% [markdown]
# Let's explore these data, we want to draw some histograms. We can visualize this with the argument ```kind= 'hist'```. We also need to specify<br> which density distribution to draw, so we need to name a particular column. The output variable, the quality of the wine, seems to be the most<br> interesting, so let's plot that first!

# %%
# specify a certain column and call the pandas plot function
df['quality'].plot(kind='hist')
# Out:
# <AxesSubplot: ylabel='Frequency'>

# %% [markdown]
# You can see, that the red wines in this dataset have quality scores from 3 to 8. So we neither have very bad quality wines nor wines with<br> the best quality scores. The score 5 is given most times. Nearly 700 wines have gotten this score.

# %% [markdown]
# Also other plots can be made with the plot function. Next we try scatter plots, where we have to specify a feature for the X and Y column.<br> And set ```kind='scatter'```.

# %%
# As you might guess from the error, we have to specify X and Y columns for pandas to plot. 
df.plot(kind='scatter', x='total sulfur dioxide', y='free sulfur dioxide')
# Out:
# <AxesSubplot: xlabel='total sulfur dioxide', ylabel='free sulfur dioxide'>

# %% [markdown]
# This is what scatter plots for continuous variables look like. You can see that when the total sulfur dioxide increases, the free sulfur<br> dioxide also increases. It is also interesting to see how different features affect the quality of red wines. Quality is a discrete variable,<br> so don't be surprised that the plot looks different.

# %%
df.plot(kind='scatter', x='quality', y='alcohol')
# Out:
# <AxesSubplot: xlabel='quality', ylabel='alcohol'>

# %% [markdown]
# This might not be a good plot to draw many conclusions, but at least we see, that wines with higher quality do not have low alcohol<br> concentrations.

# %% [markdown]
# Let's explore box plots. As histograms, they should give us a better impression on the distribution of the data

# %%
df.plot(kind='box')
# Out:
# <AxesSubplot: >

# %% [markdown]
# For most of the features we cannot distinguish their distribution, this is due to the different scales of the features. Therefore, it is<br> necessary to specify only some columns and see how that looks...

# %%
df[['fixed acidity', 'pH', 'alcohol']].plot(kind='box')
# Out:
# <AxesSubplot: >

# %%
# This still doesn't look great - it's hard to really examine these three columns since pH is 
# so different from the other two. Let's drop pH and try one more time...
df[['fixed acidity', 'alcohol']].plot(kind='box')
# Out:
# <AxesSubplot: >

# %% [markdown]
# ## Check your understanding!

# %% [markdown]
# Let's do more plotting. Checkout this [documentation](https://pandas.pydata.org/pandas-docs/stable/user_guide/visualization.html#visualization) on pandas and tryout different kinds of plots before attempting the following questions.

# %% [markdown]
# 1. Plot the average amount of ```chlorides``` for each ```quality``` value (See notebook2: Part 3, Q1).

# %%
import pandas as pd
df = pd.read_csv(r"C:\Users\sruth\Documents\Greenbootcamps\DS_Python_advanced\data\winequality-white.csv",sep=";")
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
#
#    alcohol  quality
# 0      8.8        6
# 1      9.5        6
# 2     10.1        6
# ...

# %%
import matplotlib.pyplot as plt
df.groupby('quality').mean()['chlorides'].plot(kind='bar')
# Out:
# <Axes: xlabel='quality'>

# %% [markdown]
# 2. Plot the ```alcohol``` values against ```pH``` values. Does there appear to be any relationship between the two?

# %%
df.plot(kind='scatter', x='pH', y='alcohol')  #The data points are widely scattered with no clear linear or non-linear pattern.
                                            #There does not appear to be a strong or obvious relationship between alcohol and pH based on the scatter plot.
# Out:
# <Axes: xlabel='pH', ylabel='alcohol'>

# %% [markdown]
# 3. Plot ```total_acidity``` values against ```pH``` values. Does there appear to be any relationship between the two?

# %%
df.rename(columns={'fixed acidity': 'fixed_acidity', 'volatile acidity': 'volatile_acidity'}, inplace=True)
df.eval('total_acidity = fixed_acidity + volatile_acidity', inplace=True)
df.head(4)
# Out:
#    fixed_acidity  volatile_acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
#
#    alcohol  quality  total_acidity
# 0      8.8        6           7.27
# 1      9.5        6           6.60
# 2     10.1        6           8.38
# 3      9.9        6           7.43

# %%
df.plot(kind='scatter', x='total_acidity', y='pH')
# df.plot(kind='scatter', x='pH', y='total_acidity')
# Out:
# <Axes: xlabel='total_acidity', ylabel='pH'>

# %% [markdown]
# 4. Plot a histogram of the ```quality``` values. Are they evenly distributed within the data set?

# %%
df['quality'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# 5. Plot a box plot to look at the distribution of ```citric acid```.

# %%
df[['citric acid']].plot(kind='box')
# Out:
# <Axes: >

# %%
df.describe()
# Out:
#        fixed_acidity  volatile_acidity  citric acid  residual sugar  \
# count    4898.000000       4898.000000  4898.000000     4898.000000
# mean        6.854788          0.278241     0.334192        6.391415
# std         0.843868          0.100795     0.121020        5.072058
# min         3.800000          0.080000     0.000000        0.600000
# 25%         6.300000          0.210000     0.270000        1.700000
# 50%         6.800000          0.260000     0.320000        5.200000
# 75%         7.300000          0.320000     0.390000        9.900000
# max        14.200000          1.100000     1.660000       65.800000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  4898.000000          4898.000000           4898.000000  4898.000000
# mean      0.045772            35.308085            138.360657     0.994027
# std       0.021848            17.007137             42.498065     0.002991
# ...
